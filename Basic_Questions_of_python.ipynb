# %%
# Que.1 Create a list of 5 colors and print the third color.
Colors = ["Blue","Red","Pink","Black","Yellow"]
print(Colors[2])
# Out:
# Pink

# %%
# Que.2 Create a list of marks [50, 60, 70, 80] and update the first element to 55.
marks = [50, 60, 70, 80]
marks[0] = 55
print(marks)
# Out:
# [55, 60, 70, 80]

# %%
# Que.3 Take two boolean variables x = True and y = False. Print the result of x and y.
x = True
y = False
print(x)
print(y)
# Out:
# True
# False

# %%
# Que.4 Write a Python program that checks if a number is greater than 10 and less than 50.
x = 10
print(x>10 and x<50)
# Out:
# False

# %%
x = 10
y = 40
print(x>10 and y<50)
# Out:
# False

# %%
# Que.5 Write a Python program to add two numbers 45 and 67 and print the result.
x = 45
y = 67
print(x + y)
# Out:
# 112

# %%
# Que.6 Use the or operator to check if either 5 > 10 or 2 < 8.
x = 5
y = 2
print(x>10 or y<8)
# Out:
# True

# %%
# Que.7 Given the dictionary {"name": "Bob", "age": 30}, print the age.
person = {"name": "Bob", "age": 30}
print(person["age"])
# Out:
# 30

# %%
# Que.8 Create a dictionary that stores the name and age of a person.
person = {"name": "Bob", "age": 30}
print(person)
# Out:
# {'name': 'Bob', 'age': 30}
