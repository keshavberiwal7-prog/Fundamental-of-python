# %% [markdown]
# # 1.

# %%
colors=["Red","Blue","Yellow","pink","Green"]
print(colors[2])
# Out:
# Yellow

# %% [markdown]
# # 2.

# %%
L1=[50,60,70,80]
L1[0]=55
print(L1)
# Out:
# [55, 60, 70, 80]

# %% [markdown]
# # 3.

# %%
x=True
y=False
print(x and y)
# Out:
# False

# %% [markdown]
# # 4.

# %%
x=34
y=27
print(x>10)
print(y<50)
# Out:
# True
# True

# %% [markdown]
# # 5.

# %%
x=45
y=67
print(x+y)
# Out:
# 112

# %% [markdown]
# # 6.

# %%
x=5
y=2
print(x>10 or y<8)
# Out:
# True

# %% [markdown]
# # 7.

# %%
X={"name":"Bob","age":30}
print(X["age"])
# Out:
# 30

# %% [markdown]
# # 8.

# %%
Person1={"name":"Keshav","age":25}
print(Person1)
# Out:
# {'name': 'Keshav', 'age': 25}
