# %%
#1.Check if a number is even and odd.
num = (int(input("write a number:")))
if num % 2 == 0:
    print(f'{num}: is a even number.')
else:
    print(f'{num}: is a odd number.')
# Out:
# write a number: 59
# 59: is a odd number.

# %%
#2.Check if a person is eligible to vote (age >= 18).
age = 21
if age >= 18:
    print("A person is eligible to vote")
else:
    print("A person is not eligiable to vote")
# Out:
# A person is eligible to vote

# %%
#3.Find the greatest of two numbers.
a = (int(input("write a first number:")))
b = (int(input("write a second number:")))
if a > b :
    print(f'{a}: is greater than :{b}')
else:
    print(f'{b}: is greater than :{a}')
# Out:
# write a first number: 59
# write a second number: 61
# 61: is greater than :59

# %%
#4.Check if a number is divisible by 5.
num = (int(input("write a number:")))
if num % 5 == 0:
    print(f'{num}: is divisible by 5')
else:
    print(f'{num}: is not divisible by 5')
# Out:
# write a number: 51
# 51: is not divisible by 5

# %%
#5.Check if a number is within a range (20 to 60).
num = (int(input("write a number:")))
if num > 20 and num < 60:
    print(f'{num}: is within a renge (20 to 60)')
else:
    print(f'{num}: is not within a renge (20 to 60)')
# Out:
# write a number: 50
# 50: is within a renge (20 to 60)

# %%
#6.Check if a number is multiple of both 5 and 9.
num = (int(input("write a number:")))
if num % 5 == 0 and num % 9 == 0:
    print(f'{num}: is multiple of both 5 and 9.')
else:
    print(f'{num}: is not multiple of both 5 and 9.')
# Out:
# write a number: 56
# 56: is not multiple of both 5 and 9.
